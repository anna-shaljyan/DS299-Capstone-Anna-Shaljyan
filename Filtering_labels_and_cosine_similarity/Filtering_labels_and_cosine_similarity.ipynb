# %%
# !pip install pandas openpyxl langdetect googletrans==4.0.0-rc1
# !pip install langdetect
# !pip install googletrans
# !pip install langid
# !pip install deep_translator
# !pip install translate
# !python -m spacy download en_core_web_md

# %%
import pandas as pd
import re
import ast
import spacy
import time
import langid
from langdetect import detect
from googletrans import Translator
from deep_translator import GoogleTranslator, MyMemoryTranslator
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### English-Russian books in overall dataset

# %%
# Function to preprocess text
def preprocess_text(text):
    # Remove special characters and symbols except ':', and remove '#'
    cleaned_text = re.sub(r'[^\w\s:]', '', text)
    return cleaned_text.strip()

# Function to translate text to Armenian with retry logic
def translate_to_armenian(text, max_retries=3):
    translator = Translator()
    num_retries = 0
    while num_retries < max_retries:
        try:
            if pd.notnull(text) and text.strip():
                # Preprocessing the text
                cleaned_text = preprocess_text(text)
                # Detecting language
                lang = detect(cleaned_text)
                # Translating to Armenian if the detected language is English or Russian
                if lang in ['en', 'ru']:
                    translation = translator.translate(cleaned_text, src=lang, dest='hy')
                    return translation.text
                else:
                    return text
            else:
                return text
        except Exception as e:
            print(f"Translation failed for '{text}': {e}")
            num_retries += 1
            time.sleep(2)  # Waiting for 2 seconds before retrying
    return text  # Returning original text if max retries exceeded

# Loading the Excel file
excel_path = 'armenian-books-data-translate.xlsx'
data = pd.read_excel(excel_path)

# Translating the 'Title', 'Author', 'Description' columns to Armenian
data['Title'] = data['Title'].apply(lambda x: translate_to_armenian(x, max_retries=3))
data['Author'] = data['Author'].apply(lambda x: translate_to_armenian(x, max_retries=3))
data['Description'] = data['Description'].apply(lambda x: translate_to_armenian(x, max_retries=3))

# Saving the translated data to a new Excel file
output_excel_path = 'translated-books.xlsx'
data.to_excel(output_excel_path, index=False)
# Out:
# Translation failed for '(Չ)Վեպ': No features in text.
# Translation failed for '(Չ)Վեպ': No features in text.
# Translation failed for '(Չ)Վեպ': No features in text.
# Translation failed for '1984': No features in text.
# Translation failed for '1984': No features in text.
# Translation failed for '1984': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for '987': No features in text.
# Translation failed for 'Армянское счастье, или Павликянк. Том 1': The read operation timed out
# Translation failed for 'Ջորջ Օրուել': No features in text.
# Translation failed for 'Ջորջ Օրուել': No features in text.
# Translation failed for 'Ջորջ Օրուել': No features in text.
# Translation failed for 'Օրուել Ջ.': No features in text.
# Translation failed for 'Օրուել Ջ.': No features in text.
# Translation failed for 'Օրուել Ջ.': No features in text.
# Translation failed for 'Հռիփսիմէ': No features in text.
# Translation failed for 'Հռիփսիմէ': No features in text.
# Translation failed for 'Հռիփսիմէ': No features in text.
# Translation failed for 'Ռեյ  Բրեդբերի
# (2)': No features in text.
# Translation failed for 'Ռեյ  Բրեդբերի
# (2)': No features in text.
# Translation failed for 'Ռեյ  Բրեդբերի
# (2)': No features in text.
# Translation failed for 'Է․ Լ․ Ջեյմս': No features in text.
# Translation failed for 'Է․ Լ․ Ջեյմս': No features in text.
# Translation failed for 'Է․ Լ․ Ջեյմս': No features in text.
# Translation failed for 'Ֆրեդերիկ Բեգբեդեր': No features in text.
# Translation failed for 'Ֆրեդերիկ Բեգբեդեր': No features in text.
# Translation failed for 'Ֆրեդերիկ Բեգբեդեր': No features in text.
# Translation failed for 'Բեգբեդեր Ֆ․': No features in text.
# Translation failed for 'Բեգբեդեր Ֆ․': No features in text.
# Translation failed for 'Բեգբեդեր Ֆ․': No features in text.
# Translation failed for 'Գրիգ': No features in text.
# Translation failed for 'Գրիգ': No features in text.
# Translation failed for 'Գրիգ': No features in text.
# Translation failed for 'The short fiction of Karine Khodikyan can be described as intellectual fiction for women. These short stories with a 'mystical touch' tell stories about women - young and old, happy and sad; even when the protagonist is not a woman, the story will immerse you into the life of a woman, revealing her role in anything and everything. This book was published with the support of the Ministry of Culture of the Republic of Armenia under the 'Armenian Literature in Translation' Program. Translated from the Armenian by Nazareth Seferian Proofread by Michael Wharton': The read operation timed out

# %% [markdown]
# ### Defining paths to goodreads scraped datasets from genres : horror, romance, fantasy and mystery

# %%
excel_path_mystery = 'goodreads-mystery.xlsx'
excel_path_romance = 'goodreads-romance.xlsx'
excel_path_horror = 'goodreads-horror.xlsx'
excel_path_fantasy = 'goodreads-fantasy.xlsx'

# %% [markdown]
# ### Goodreads mystery books data translation

# %%
# Loading the Excel file and converting specific columns to string
data_cleaned = pd.read_excel(excel_path_mystery, dtype={'Title': str, 'Author': str, 'Description': str})

# Translating the 'Title', 'Author', 'Description' columns to Armenian
data_cleaned['Title'] = data_cleaned['Title'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Author'] = data_cleaned['Author'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Description'] = data_cleaned['Description'].apply(lambda x: translate_to_armenian(x, max_retries=2))

# Saving the translated data to a new Excel file
output_excel_path = 'translated-mystery-books.xlsx'
data_cleaned.to_excel(output_excel_path, index=False)

# %% [markdown]
# ### Goodreads romance books data translation in two steps

# %%
# Loading the Excel file and converting specific columns to string
data_cleaned = pd.read_excel(excel_path_romance, dtype={'Title': str, 'Author': str, 'Description': str})

# Removing content within brackets in the 'Title' column
data_cleaned['Title'] = data_cleaned['Title'].str.replace(r'\([^()]*\)', '', regex=True)

# Translating the 'Title', 'Author', 'Description' columns to Armenian
data_cleaned['Title'] = data_cleaned['Title'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Author'] = data_cleaned['Author'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Description'] = data_cleaned['Description'].apply(lambda x: translate_to_armenian(x, max_retries=2))

# Saving the translated data to a new Excel file
output_excel_path = 'translated-romance-books.xlsx'
data_cleaned.to_excel(output_excel_path, index=False)

# %%
# Function to preprocess text and remove numbers and symbols
def preprocess_text_new(text):
    # Removing numbers
    text_without_numbers = re.sub(r'\d+', '', text)
    # Removing special characters and symbols except ':', and remove '#'
    cleaned_text = re.sub(r'[^\w\s:]', '', text_without_numbers)
    return cleaned_text.strip()

# Function to translate text to Armenian with retry logic
def translate_to_armenian_batch(text_list, max_retries=2, batch_size=10):
    num_retries = 0
    translations = []
    while num_retries < max_retries:
        try:
            if text_list:
                # If Google Translate fails, using MyMemoryTranslator as a backup
                translator = MyMemoryTranslator(source='english', target='armenian')
                # Batch translation requests to avoid making too many requests
                for i in range(0, len(text_list), batch_size):
                    batch_text = text_list[i:i+batch_size]
                    batch_translations = translator.translate_batch(batch_text)
                    translations.extend(batch_translations)
                return translations, True  # Returning translations and a flag indicating success
            else:
                return text_list, False  # Returning original text and failure flag
        except Exception as e:
            print(f"MyMemory Translate batch failed: {e}")
            num_retries += 1
            time.sleep(2)  # Waiting for 2 seconds before retrying
    return text_list, False  # Returning original text and failure flag if max retries exceeded

# Loading the Excel file and convert specific columns to string
excel_path = 'translated-romance-books.xlsx'
data_cleaned = pd.read_excel(excel_path, dtype={'Title': str, 'Author': str, 'Description': str})

# Preprocessing and removing numbers and symbols from the 'Title' column
data_cleaned['Title'] = data_cleaned['Title'].apply(lambda x: preprocess_text_new(x))

# Tracking the count of successful translations
success_count = 0

# Batch size for translations
batch_size = 100

# Translating the 'Title' column to Armenian using MyMemoryTranslator
titles_to_translate = data_cleaned['Title'].tolist()
num_titles = len(titles_to_translate)
start_index = 0
while start_index < num_titles:
    end_index = min(start_index + batch_size, num_titles)
    batch_titles = titles_to_translate[start_index:end_index]
    translations, success = translate_to_armenian_batch(batch_titles, max_retries=2, batch_size=batch_size)
    if success:
        for i, translation in enumerate(translations):
            data_cleaned.at[start_index + i, 'Title'] = translation
        success_count += len(translations)
    print(f"Translated {success_count} out of {num_titles} titles successfully.")
    print(f"Waiting for 1 second before next translation...")
    time.sleep(1)
    start_index = end_index

# Saving the translated data to a new Excel file
output_excel_path = 'translated-romance-books-new.xlsx.xlsx'
data_cleaned.to_excel(output_excel_path, index=False)

print("All translations completed.")
# Out:
# Translated 100 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 200 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 300 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 400 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 500 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 600 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# Translated 644 out of 644 titles successfully.
# Waiting for 1 second before next translation...
# All translations completed.

# %% [markdown]
# ### Goodreads horror books translation

# %%
# Loading the Excel file and convert specific columns to string
data_cleaned = pd.read_excel(excel_path_horror, dtype={'Title': str, 'Author': str, 'Description': str})

# Removing content within brackets in the 'Title' column
data_cleaned['Title'] = data_cleaned['Title'].str.replace(r'\([^()]*\)', '', regex=True)

# Translating the 'Title', 'Author', 'Description' columns to Armenian
data_cleaned['Title'] = data_cleaned['Title'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Author'] = data_cleaned['Author'].apply(lambda x: translate_to_armenian(x, max_retries=2))
data_cleaned['Description'] = data_cleaned['Description'].apply(lambda x: translate_to_armenian(x, max_retries=2))

# Saving the translated data to a new Excel file
output_excel_path = 'translated-horror-books.xlsx'
data_cleaned.to_excel(output_excel_path, index=False)

# %% [markdown]
# ### Goodreads fantasy books translation in two steps

# %%
# Loading the Excel file and convert specific columns to string
excel_path = 'translated-fantasy-books.xlsx'
data_cleaned = pd.read_excel(excel_path, dtype={'Title': str, 'Author': str, 'Description': str})

# Preprocessing and removing numbers and symbols from the 'Title' column
data_cleaned['Title'] = data_cleaned['Title'].apply(lambda x: preprocess_text_new(x))

# Tracking the count of successful translations
success_count = 0

# Batch size for translations
batch_size = 100

# Translating the 'Title' column to Armenian using MyMemoryTranslator
titles_to_translate = data_cleaned['Title'].tolist()
num_titles = len(titles_to_translate)
start_index = 0
while start_index < num_titles:
    end_index = min(start_index + batch_size, num_titles)
    batch_titles = titles_to_translate[start_index:end_index]
    translations, success = translate_to_armenian_batch(batch_titles, max_retries=2, batch_size=batch_size)
    if success:
        for i, translation in enumerate(translations):
            data_cleaned.at[start_index + i, 'Title'] = translation
        success_count += len(translations)
    print(f"Translated {success_count} out of {num_titles} titles successfully.")
    print(f"Waiting for 1 second before next translation...")
    time.sleep(1)
    start_index = end_index

# Saving the translated data to a new Excel file
output_excel_path = 'translated-fantasy-books-new.xlsx'
data_cleaned.to_excel(output_excel_path, index=False)

print("All translations completed.")

# %% [markdown]
# ## Cosine Similarity

# %% [markdown]
# #### With 0.9 threshold

# %%
# Loading the data from the Excel file
excel_path = 'goodreads_data_with_additional_info.xlsx'
data = pd.read_excel(excel_path)

# Function to preprocess and clean text using SpaCy
nlp = spacy.load("en_core_web_md")

def clean_text_with_spacy(text):
    doc = nlp(text.lower())
    return " ".join([token.lemma_ for token in doc if not token.is_stop and token.is_alpha])

# List of popular book genres
popular_genres = ['Mystery', 'Thriller', 'Romance', 'Science Fiction', 'Fantasy', 'Historical Fiction',
                  'Horror', 'Crime', 'Biography', 'Memoir', 'Self-Help', 'Young Adult', "Children's",
                  'Adventure', 'Contemporary', 'Dystopian', 'Suspense', 'Poetry', 'Comedy', 'Drama', 'Action',
                  'Paranormal', 'Urban Fantasy', 'Science Fantasy', 'Humor', 'Travel', 'Philosophy', 'Classic']

# Preprocess and clean popular genres
cleaned_popular_genres = [clean_text_with_spacy(genre) for genre in popular_genres]

# Creating an empty list to store top labels
top_labels = []

# Iterating over each row in the DataFrame
for index, row in data.iterrows():
    # Extracting labels from the 'Labels' column
    labels = ast.literal_eval(row['Labels'])

    # Removing empty strings from the list
    labels = [label for label in labels if label]

    # Preprocessing and cleaning labels
    cleaned_labels = [clean_text_with_spacy(label) for label in labels]

    # Combining both lists for vectorization
    combined_list = cleaned_labels + cleaned_popular_genres

    # Calculating word vectors for combined list
    vectors = [nlp(text).vector for text in combined_list]

    # Calculating cosine similarity
    cosine_sim = cosine_similarity(vectors)

    # Threshold for similarity
    threshold = 0.9

    # Filtering labels based on cosine similarity
    filtered_indices = [i for i, label in enumerate(labels) if any(cosine_sim[i, j] > threshold for j in range(len(cleaned_labels), len(combined_list)))]

    # Calculating maximum similarity score for each label with popular genres
    max_similarities = [max(cosine_sim[i, len(cleaned_labels):]) for i in filtered_indices]

    # Checking if any labels passed the similarity threshold
    if filtered_indices:
        # Getting the index of the label with the highest similarity score
        top_label_index = filtered_indices[max_similarities.index(max(max_similarities))]

        # Retrieving the top label
        top_label = labels[top_label_index]

        # Appending the top label to the list
        top_labels.append(top_label)
    else:
        # If no label met the similarity threshold, appending None
        top_labels.append(None)

    # Printing progress update
    print(f"Processed {index + 1} books out of {len(data)}")

# Adding the top labels to the DataFrame
data['Top Label'] = top_labels

# Saving the updated DataFrame to a new Excel file
data.to_excel('goodreads_dataset-final-version.xlsx', index=False)
# Out:
# Processed 1 books out of 882
# Processed 2 books out of 882
# Processed 3 books out of 882
# Processed 4 books out of 882
# Processed 5 books out of 882
# Processed 6 books out of 882
# Processed 7 books out of 882
# Processed 8 books out of 882
# Processed 9 books out of 882
# Processed 10 books out of 882
# Processed 11 books out of 882
# Processed 12 books out of 882
# Processed 13 books out of 882
# Processed 14 books out of 882
# Processed 15 books out of 882
# Processed 16 books out of 882
# Processed 17 books out of 882
# Processed 18 books out of 882
# Processed 19 books out of 882
# Processed 20 books out of 882
# Processed 21 books out of 882
# Processed 22 books out of 882
# Processed 23 books out of 882
# Processed 24 books out of 882
# Processed 25 books out of 882
# Processed 26 books out of 882
# Processed 27 books out of 882
# Processed 28 books out of 882
# Processed 29 books out of 882
# Processed 30 books out of 882
# Processed 31 books out of 882
# Processed 32 books out of 882
# Processed 33 books out of 882
# Processed 34 books out of 882
# Processed 35 books out of 882
# Processed 36 books out of 882
# Processed 37 books out of 882
# Processed 38 books out of 882
# Processed 39 books out of 882
# Processed 40 books out of 882
# Processed 41 books out of 882
# Processed 42 books out of 882
# Processed 43 books out of 882
# Processed 44 books out of 882
# Processed 45 books out of 882
# Processed 46 books out of 882
# Processed 47 books out of 882
# Processed 48 books out of 882
# Processed 49 books out of 882
# Processed 50 books out of 882
# Processed 51 books out of 882
# Processed 52 books out of 882
# Processed 53 books out of 882
# Processed 54 books out of 882
# Processed 55 books out of 882
# Processed 56 books out of 882
# Processed 57 books out of 882
# Processed 58 books out of 882
# Processed 59 books out of 882
# Processed 60 books out of 882
# Processed 61 books out of 882
# Processed 62 books out of 882
# Processed 63 books out of 882
# Processed 64 books out of 882
# Processed 65 books out of 882
# Processed 66 books out of 882
# Processed 67 books out of 882
# Processed 68 books out of 882
# Processed 69 books out of 882
# Processed 70 books out of 882
# Processed 71 books out of 882
# Processed 72 books out of 882
# Processed 73 books out of 882
# Processed 74 books out of 882
# Processed 75 books out of 882
# Processed 76 books out of 882
# Processed 77 books out of 882
# Processed 78 books out of 882
# Processed 79 books out of 882
# Processed 80 books out of 882
# Processed 81 books out of 882
# Processed 82 books out of 882
# Processed 83 books out of 882
# Processed 84 books out of 882
# Processed 85 books out of 882
# Processed 86 books out of 882
# Processed 87 books out of 882
# Processed 88 books out of 882
# Processed 89 books out of 882
# Processed 90 books out of 882
# Processed 91 books out of 882
# Processed 92 books out of 882
# Processed 93 books out of 882
# Processed 94 books out of 882
# Processed 95 books out of 882
# Processed 96 books out of 882
# Processed 97 books out of 882
# Processed 98 books out of 882
# Processed 99 books out of 882
# Processed 100 books out of 882
# Processed 101 books out of 882
# Processed 102 books out of 882
# Processed 103 books out of 882
# Processed 104 books out of 882
# Processed 105 books out of 882
# Processed 106 books out of 882
# Processed 107 books out of 882
# Processed 108 books out of 882
# Processed 109 books out of 882
# Processed 110 books out of 882
# Processed 111 books out of 882
# Processed 112 books out of 882
# Processed 113 books out of 882
# Processed 114 books out of 882
# Processed 115 books out of 882
# Processed 116 books out of 882
# Processed 117 books out of 882
# Processed 118 books out of 882
# Processed 119 books out of 882
# Processed 120 books out of 882
# Processed 121 books out of 882
# Processed 122 books out of 882
# Processed 123 books out of 882
# Processed 124 books out of 882
# Processed 125 books out of 882
# Processed 126 books out of 882
# Processed 127 books out of 882
# Processed 128 books out of 882
# Processed 129 books out of 882
# Processed 130 books out of 882
# Processed 131 books out of 882
# Processed 132 books out of 882
# Processed 133 books out of 882
# Processed 134 books out of 882
# Processed 135 books out of 882
# Processed 136 books out of 882
# Processed 137 books out of 882
# Processed 138 books out of 882
# Processed 139 books out of 882
# Processed 140 books out of 882
# Processed 141 books out of 882
# Processed 142 books out of 882
# Processed 143 books out of 882
# Processed 144 books out of 882
# Processed 145 books out of 882
# Processed 146 books out of 882
# Processed 147 books out of 882
# Processed 148 books out of 882
# Processed 149 books out of 882
# Processed 150 books out of 882
# Processed 151 books out of 882
# Processed 152 books out of 882
# Processed 153 books out of 882
# Processed 154 books out of 882
# Processed 155 books out of 882
# Processed 156 books out of 882
# Processed 157 books out of 882
# Processed 158 books out of 882
# Processed 159 books out of 882
# Processed 160 books out of 882
# Processed 161 books out of 882
# Processed 162 books out of 882
# Processed 163 books out of 882
# Processed 164 books out of 882
# Processed 165 books out of 882
# Processed 166 books out of 882
# Processed 167 books out of 882
# Processed 168 books out of 882
# Processed 169 books out of 882
# Processed 170 books out of 882
# Processed 171 books out of 882
# Processed 172 books out of 882
# Processed 173 books out of 882
# Processed 174 books out of 882
# Processed 175 books out of 882
# Processed 176 books out of 882
# Processed 177 books out of 882
# Processed 178 books out of 882
# Processed 179 books out of 882
# Processed 180 books out of 882
# Processed 181 books out of 882
# Processed 182 books out of 882
# Processed 183 books out of 882
# Processed 184 books out of 882
# Processed 185 books out of 882
# Processed 186 books out of 882
# Processed 187 books out of 882
# Processed 188 books out of 882
# Processed 189 books out of 882
# Processed 190 books out of 882
# Processed 191 books out of 882
# Processed 192 books out of 882
# Processed 193 books out of 882
# Processed 194 books out of 882
# Processed 195 books out of 882
# Processed 196 books out of 882
# Processed 197 books out of 882
# Processed 198 books out of 882
# Processed 199 books out of 882
# Processed 200 books out of 882
# Processed 201 books out of 882
# Processed 202 books out of 882
# Processed 203 books out of 882
# Processed 204 books out of 882
# Processed 205 books out of 882
# Processed 206 books out of 882
# Processed 207 books out of 882
# Processed 208 books out of 882
# Processed 209 books out of 882
# Processed 210 books out of 882
# Processed 211 books out of 882
# Processed 212 books out of 882
# Processed 213 books out of 882
# Processed 214 books out of 882
# Processed 215 books out of 882
# Processed 216 books out of 882
# Processed 217 books out of 882
# Processed 218 books out of 882
# Processed 219 books out of 882
# Processed 220 books out of 882
# Processed 221 books out of 882
# Processed 222 books out of 882
# Processed 223 books out of 882
# Processed 224 books out of 882
# Processed 225 books out of 882
# Processed 226 books out of 882
# Processed 227 books out of 882
# Processed 228 books out of 882
# Processed 229 books out of 882
# Processed 230 books out of 882
# Processed 231 books out of 882
# Processed 232 books out of 882
# Processed 233 books out of 882
# Processed 234 books out of 882
# Processed 235 books out of 882
# Processed 236 books out of 882
# Processed 237 books out of 882
# Processed 238 books out of 882
# Processed 239 books out of 882
# Processed 240 books out of 882
# Processed 241 books out of 882
# Processed 242 books out of 882
# Processed 243 books out of 882
# Processed 244 books out of 882
# Processed 245 books out of 882
# Processed 246 books out of 882
# Processed 247 books out of 882
# Processed 248 books out of 882
# Processed 249 books out of 882
# Processed 250 books out of 882
# Processed 251 books out of 882
# Processed 252 books out of 882
# Processed 253 books out of 882
# Processed 254 books out of 882
# Processed 255 books out of 882
# Processed 256 books out of 882
# Processed 257 books out of 882
# Processed 258 books out of 882
# Processed 259 books out of 882
# Processed 260 books out of 882
# Processed 261 books out of 882
# Processed 262 books out of 882
# Processed 263 books out of 882
# Processed 264 books out of 882
# Processed 265 books out of 882
# Processed 266 books out of 882
# Processed 267 books out of 882
# Processed 268 books out of 882
# Processed 269 books out of 882
# Processed 270 books out of 882
# Processed 271 books out of 882
# Processed 272 books out of 882
# Processed 273 books out of 882
# Processed 274 books out of 882
# Processed 275 books out of 882
# Processed 276 books out of 882
# Processed 277 books out of 882
# Processed 278 books out of 882
# Processed 279 books out of 882
# Processed 280 books out of 882
# Processed 281 books out of 882
# Processed 282 books out of 882
# Processed 283 books out of 882
# Processed 284 books out of 882
# Processed 285 books out of 882
# Processed 286 books out of 882
# Processed 287 books out of 882
# Processed 288 books out of 882
# Processed 289 books out of 882
# Processed 290 books out of 882
# Processed 291 books out of 882
# Processed 292 books out of 882
# Processed 293 books out of 882
# Processed 294 books out of 882
# Processed 295 books out of 882
# Processed 296 books out of 882
# Processed 297 books out of 882
# Processed 298 books out of 882
# Processed 299 books out of 882
# Processed 300 books out of 882
# Processed 301 books out of 882
# Processed 302 books out of 882
# Processed 303 books out of 882
# Processed 304 books out of 882
# Processed 305 books out of 882
# Processed 306 books out of 882
# Processed 307 books out of 882
# Processed 308 books out of 882
# Processed 309 books out of 882
# Processed 310 books out of 882
# Processed 311 books out of 882
# Processed 312 books out of 882
# Processed 313 books out of 882
# Processed 314 books out of 882
# Processed 315 books out of 882
# Processed 316 books out of 882
# Processed 317 books out of 882
# Processed 318 books out of 882
# Processed 319 books out of 882
# Processed 320 books out of 882
# Processed 321 books out of 882
# Processed 322 books out of 882
# Processed 323 books out of 882
# Processed 324 books out of 882
# Processed 325 books out of 882
# Processed 326 books out of 882
# Processed 327 books out of 882
# Processed 328 books out of 882
# Processed 329 books out of 882
# Processed 330 books out of 882
# Processed 331 books out of 882
# Processed 332 books out of 882
# Processed 333 books out of 882
# Processed 334 books out of 882
# Processed 335 books out of 882
# Processed 336 books out of 882
# Processed 337 books out of 882
# Processed 338 books out of 882
# Processed 339 books out of 882
# Processed 340 books out of 882
# Processed 341 books out of 882
# Processed 342 books out of 882
# Processed 343 books out of 882
# Processed 344 books out of 882
# Processed 345 books out of 882
# Processed 346 books out of 882
# Processed 347 books out of 882
# Processed 348 books out of 882
# Processed 349 books out of 882
# Processed 350 books out of 882
# Processed 351 books out of 882
# Processed 352 books out of 882
# Processed 353 books out of 882
# Processed 354 books out of 882
# Processed 355 books out of 882
# Processed 356 books out of 882
# Processed 357 books out of 882
# Processed 358 books out of 882
# Processed 359 books out of 882
# Processed 360 books out of 882
# Processed 361 books out of 882
# Processed 362 books out of 882
# Processed 363 books out of 882
# Processed 364 books out of 882
# Processed 365 books out of 882
# Processed 366 books out of 882
# Processed 367 books out of 882
# Processed 368 books out of 882
# Processed 369 books out of 882
# Processed 370 books out of 882
# Processed 371 books out of 882
# Processed 372 books out of 882
# Processed 373 books out of 882
# Processed 374 books out of 882
# Processed 375 books out of 882
# Processed 376 books out of 882
# Processed 377 books out of 882
# Processed 378 books out of 882
# Processed 379 books out of 882
# Processed 380 books out of 882
# Processed 381 books out of 882
# Processed 382 books out of 882
# Processed 383 books out of 882
# Processed 384 books out of 882
# Processed 385 books out of 882
# Processed 386 books out of 882
# Processed 387 books out of 882
# Processed 388 books out of 882
# Processed 389 books out of 882
# Processed 390 books out of 882
# Processed 391 books out of 882
# Processed 392 books out of 882
# Processed 393 books out of 882
# Processed 394 books out of 882
# Processed 395 books out of 882
# Processed 396 books out of 882
# Processed 397 books out of 882
# Processed 398 books out of 882
# Processed 399 books out of 882
# Processed 400 books out of 882
# Processed 401 books out of 882
# Processed 402 books out of 882
# Processed 403 books out of 882
# Processed 404 books out of 882
# Processed 405 books out of 882
# Processed 406 books out of 882
# Processed 407 books out of 882
# Processed 408 books out of 882
# Processed 409 books out of 882
# Processed 410 books out of 882
# Processed 411 books out of 882
# Processed 412 books out of 882
# Processed 413 books out of 882
# Processed 414 books out of 882
# Processed 415 books out of 882
# Processed 416 books out of 882
# Processed 417 books out of 882
# Processed 418 books out of 882
# Processed 419 books out of 882
# Processed 420 books out of 882
# Processed 421 books out of 882
# Processed 422 books out of 882
# Processed 423 books out of 882
# Processed 424 books out of 882
# Processed 425 books out of 882
# Processed 426 books out of 882
# Processed 427 books out of 882
# Processed 428 books out of 882
# Processed 429 books out of 882
# Processed 430 books out of 882
# Processed 431 books out of 882
# Processed 432 books out of 882
# Processed 433 books out of 882
# Processed 434 books out of 882
# Processed 435 books out of 882
# Processed 436 books out of 882
# Processed 437 books out of 882
# Processed 438 books out of 882
# Processed 439 books out of 882
# Processed 440 books out of 882
# Processed 441 books out of 882
# Processed 442 books out of 882
# Processed 443 books out of 882
# Processed 444 books out of 882
# Processed 445 books out of 882
# Processed 446 books out of 882
# Processed 447 books out of 882
# Processed 448 books out of 882
# Processed 449 books out of 882
# Processed 450 books out of 882
# Processed 451 books out of 882
# Processed 452 books out of 882
# Processed 453 books out of 882
# Processed 454 books out of 882
# Processed 455 books out of 882
# Processed 456 books out of 882
# Processed 457 books out of 882
# Processed 458 books out of 882
# Processed 459 books out of 882
# Processed 460 books out of 882
# Processed 461 books out of 882
# Processed 462 books out of 882
# Processed 463 books out of 882
# Processed 464 books out of 882
# Processed 465 books out of 882
# Processed 466 books out of 882
# Processed 467 books out of 882
# Processed 468 books out of 882
# Processed 469 books out of 882
# Processed 470 books out of 882
# Processed 471 books out of 882
# Processed 472 books out of 882
# Processed 473 books out of 882
# Processed 474 books out of 882
# Processed 475 books out of 882
# Processed 476 books out of 882
# Processed 477 books out of 882
# Processed 478 books out of 882
# Processed 479 books out of 882
# Processed 480 books out of 882
# Processed 481 books out of 882
# Processed 482 books out of 882
# Processed 483 books out of 882
# Processed 484 books out of 882
# Processed 485 books out of 882
# Processed 486 books out of 882
# Processed 487 books out of 882
# Processed 488 books out of 882
# Processed 489 books out of 882
# Processed 490 books out of 882
# Processed 491 books out of 882
# Processed 492 books out of 882
# Processed 493 books out of 882
# Processed 494 books out of 882
# Processed 495 books out of 882
# Processed 496 books out of 882
# Processed 497 books out of 882
# Processed 498 books out of 882
# Processed 499 books out of 882
# Processed 500 books out of 882
# Processed 501 books out of 882
# Processed 502 books out of 882
# Processed 503 books out of 882
# Processed 504 books out of 882
# Processed 505 books out of 882
# Processed 506 books out of 882
# Processed 507 books out of 882
# Processed 508 books out of 882
# Processed 509 books out of 882
# Processed 510 books out of 882
# Processed 511 books out of 882
# Processed 512 books out of 882
# Processed 513 books out of 882
# Processed 514 books out of 882
# Processed 515 books out of 882
# Processed 516 books out of 882
# Processed 517 books out of 882
# Processed 518 books out of 882
# Processed 519 books out of 882
# Processed 520 books out of 882
# Processed 521 books out of 882
# Processed 522 books out of 882
# Processed 523 books out of 882
# Processed 524 books out of 882
# Processed 525 books out of 882
# Processed 526 books out of 882
# Processed 527 books out of 882
# Processed 528 books out of 882
# Processed 529 books out of 882
# Processed 530 books out of 882
# Processed 531 books out of 882
# Processed 532 books out of 882
# Processed 533 books out of 882
# Processed 534 books out of 882
# Processed 535 books out of 882
# Processed 536 books out of 882
# Processed 537 books out of 882
# Processed 538 books out of 882
# Processed 539 books out of 882
# Processed 540 books out of 882
# Processed 541 books out of 882
# Processed 542 books out of 882
# Processed 543 books out of 882
# Processed 544 books out of 882
# Processed 545 books out of 882
# Processed 546 books out of 882
# Processed 547 books out of 882
# Processed 548 books out of 882
# Processed 549 books out of 882
# Processed 550 books out of 882
# Processed 551 books out of 882
# Processed 552 books out of 882
# Processed 553 books out of 882
# Processed 554 books out of 882
# Processed 555 books out of 882
# Processed 556 books out of 882
# Processed 557 books out of 882
# Processed 558 books out of 882
# Processed 559 books out of 882
# Processed 560 books out of 882
# Processed 561 books out of 882
# Processed 562 books out of 882
# Processed 563 books out of 882
# Processed 564 books out of 882
# Processed 565 books out of 882
# Processed 566 books out of 882
# Processed 567 books out of 882
# Processed 568 books out of 882
# Processed 569 books out of 882
# Processed 570 books out of 882
# Processed 571 books out of 882
# Processed 572 books out of 882
# Processed 573 books out of 882
# Processed 574 books out of 882
# Processed 575 books out of 882
# Processed 576 books out of 882
# Processed 577 books out of 882
# Processed 578 books out of 882
# Processed 579 books out of 882
# Processed 580 books out of 882
# Processed 581 books out of 882
# Processed 582 books out of 882
# Processed 583 books out of 882
# Processed 584 books out of 882
# Processed 585 books out of 882
# Processed 586 books out of 882
# Processed 587 books out of 882
# Processed 588 books out of 882
# Processed 589 books out of 882
# Processed 590 books out of 882
# Processed 591 books out of 882
# Processed 592 books out of 882
# Processed 593 books out of 882
# Processed 594 books out of 882
# Processed 595 books out of 882
# Processed 596 books out of 882
# Processed 597 books out of 882
# Processed 598 books out of 882
# Processed 599 books out of 882
# Processed 600 books out of 882
# Processed 601 books out of 882
# Processed 602 books out of 882
# Processed 603 books out of 882
# Processed 604 books out of 882
# Processed 605 books out of 882
# Processed 606 books out of 882
# Processed 607 books out of 882
# Processed 608 books out of 882
# Processed 609 books out of 882
# Processed 610 books out of 882
# Processed 611 books out of 882
# Processed 612 books out of 882
# Processed 613 books out of 882
# Processed 614 books out of 882
# Processed 615 books out of 882
# Processed 616 books out of 882
# Processed 617 books out of 882
# Processed 618 books out of 882
# Processed 619 books out of 882
# Processed 620 books out of 882
# Processed 621 books out of 882
# Processed 622 books out of 882
# Processed 623 books out of 882
# Processed 624 books out of 882
# Processed 625 books out of 882
# Processed 626 books out of 882
# Processed 627 books out of 882
# Processed 628 books out of 882
# Processed 629 books out of 882
# Processed 630 books out of 882
# Processed 631 books out of 882
# Processed 632 books out of 882
# Processed 633 books out of 882
# Processed 634 books out of 882
# Processed 635 books out of 882
# Processed 636 books out of 882
# Processed 637 books out of 882
# Processed 638 books out of 882
# Processed 639 books out of 882
# Processed 640 books out of 882
# Processed 641 books out of 882
# Processed 642 books out of 882
# Processed 643 books out of 882
# Processed 644 books out of 882
# Processed 645 books out of 882
# Processed 646 books out of 882
# Processed 647 books out of 882
# Processed 648 books out of 882
# Processed 649 books out of 882
# Processed 650 books out of 882
# Processed 651 books out of 882
# Processed 652 books out of 882
# Processed 653 books out of 882
# Processed 654 books out of 882
# Processed 655 books out of 882
# Processed 656 books out of 882
# Processed 657 books out of 882
# Processed 658 books out of 882
# Processed 659 books out of 882
# Processed 660 books out of 882
# Processed 661 books out of 882
# Processed 662 books out of 882
# Processed 663 books out of 882
# Processed 664 books out of 882
# Processed 665 books out of 882
# Processed 666 books out of 882
# Processed 667 books out of 882
# Processed 668 books out of 882
# Processed 669 books out of 882
# Processed 670 books out of 882
# Processed 671 books out of 882
# Processed 672 books out of 882
# Processed 673 books out of 882
# Processed 674 books out of 882
# Processed 675 books out of 882
# Processed 676 books out of 882
# Processed 677 books out of 882
# Processed 678 books out of 882
# Processed 679 books out of 882
# Processed 680 books out of 882
# Processed 681 books out of 882
# Processed 682 books out of 882
# Processed 683 books out of 882
# Processed 684 books out of 882
# Processed 685 books out of 882
# Processed 686 books out of 882
# Processed 687 books out of 882
# Processed 688 books out of 882
# Processed 689 books out of 882
# Processed 690 books out of 882
# Processed 691 books out of 882
# Processed 692 books out of 882
# Processed 693 books out of 882
# Processed 694 books out of 882
# Processed 695 books out of 882
# Processed 696 books out of 882
# Processed 697 books out of 882
# Processed 698 books out of 882
# Processed 699 books out of 882
# Processed 700 books out of 882
# Processed 701 books out of 882
# Processed 702 books out of 882
# Processed 703 books out of 882
# Processed 704 books out of 882
# Processed 705 books out of 882
# Processed 706 books out of 882
# Processed 707 books out of 882
# Processed 708 books out of 882
# Processed 709 books out of 882
# Processed 710 books out of 882
# Processed 711 books out of 882
# Processed 712 books out of 882
# Processed 713 books out of 882
# Processed 714 books out of 882
# Processed 715 books out of 882
# Processed 716 books out of 882
# Processed 717 books out of 882
# Processed 718 books out of 882
# Processed 719 books out of 882
# Processed 720 books out of 882
# Processed 721 books out of 882
# Processed 722 books out of 882
# Processed 723 books out of 882
# Processed 724 books out of 882
# Processed 725 books out of 882
# Processed 726 books out of 882
# Processed 727 books out of 882
# Processed 728 books out of 882
# Processed 729 books out of 882
# Processed 730 books out of 882
# Processed 731 books out of 882
# Processed 732 books out of 882
# Processed 733 books out of 882
# Processed 734 books out of 882
# Processed 735 books out of 882
# Processed 736 books out of 882
# Processed 737 books out of 882
# Processed 738 books out of 882
# Processed 739 books out of 882
# Processed 740 books out of 882
# Processed 741 books out of 882
# Processed 742 books out of 882
# Processed 743 books out of 882
# Processed 744 books out of 882
# Processed 745 books out of 882
# Processed 746 books out of 882
# Processed 747 books out of 882
# Processed 748 books out of 882
# Processed 749 books out of 882
# Processed 750 books out of 882
# Processed 751 books out of 882
# Processed 752 books out of 882
# Processed 753 books out of 882
# Processed 754 books out of 882
# Processed 755 books out of 882
# Processed 756 books out of 882
# Processed 757 books out of 882
# Processed 758 books out of 882
# Processed 759 books out of 882
# Processed 760 books out of 882
# Processed 761 books out of 882
# Processed 762 books out of 882
# Processed 763 books out of 882
# Processed 764 books out of 882
# Processed 765 books out of 882
# Processed 766 books out of 882
# Processed 767 books out of 882
# Processed 768 books out of 882
# Processed 769 books out of 882
# Processed 770 books out of 882
# Processed 771 books out of 882
# Processed 772 books out of 882
# Processed 773 books out of 882
# Processed 774 books out of 882
# Processed 775 books out of 882
# Processed 776 books out of 882
# Processed 777 books out of 882
# Processed 778 books out of 882
# Processed 779 books out of 882
# Processed 780 books out of 882
# Processed 781 books out of 882
# Processed 782 books out of 882
# Processed 783 books out of 882
# Processed 784 books out of 882
# Processed 785 books out of 882
# Processed 786 books out of 882
# Processed 787 books out of 882
# Processed 788 books out of 882
# Processed 789 books out of 882
# Processed 790 books out of 882
# Processed 791 books out of 882
# Processed 792 books out of 882
# Processed 793 books out of 882
# Processed 794 books out of 882
# Processed 795 books out of 882
# Processed 796 books out of 882
# Processed 797 books out of 882
# Processed 798 books out of 882
# Processed 799 books out of 882
# Processed 800 books out of 882
# Processed 801 books out of 882
# Processed 802 books out of 882
# Processed 803 books out of 882
# Processed 804 books out of 882
# Processed 805 books out of 882
# Processed 806 books out of 882
# Processed 807 books out of 882
# Processed 808 books out of 882
# Processed 809 books out of 882
# Processed 810 books out of 882
# Processed 811 books out of 882
# Processed 812 books out of 882
# Processed 813 books out of 882
# Processed 814 books out of 882
# Processed 815 books out of 882
# Processed 816 books out of 882
# Processed 817 books out of 882
# Processed 818 books out of 882
# Processed 819 books out of 882
# Processed 820 books out of 882
# Processed 821 books out of 882
# Processed 822 books out of 882
# Processed 823 books out of 882
# Processed 824 books out of 882
# Processed 825 books out of 882
# Processed 826 books out of 882
# Processed 827 books out of 882
# Processed 828 books out of 882
# Processed 829 books out of 882
# Processed 830 books out of 882
# Processed 831 books out of 882
# Processed 832 books out of 882
# Processed 833 books out of 882
# Processed 834 books out of 882
# Processed 835 books out of 882
# Processed 836 books out of 882
# Processed 837 books out of 882
# Processed 838 books out of 882
# Processed 839 books out of 882
# Processed 840 books out of 882
# Processed 841 books out of 882
# Processed 842 books out of 882
# Processed 843 books out of 882
# Processed 844 books out of 882
# Processed 845 books out of 882
# Processed 846 books out of 882
# Processed 847 books out of 882
# Processed 848 books out of 882
# Processed 849 books out of 882
# Processed 850 books out of 882
# Processed 851 books out of 882
# Processed 852 books out of 882
# Processed 853 books out of 882
# Processed 854 books out of 882
# Processed 855 books out of 882
# Processed 856 books out of 882
# Processed 857 books out of 882
# Processed 858 books out of 882
# Processed 859 books out of 882
# Processed 860 books out of 882
# Processed 861 books out of 882
# Processed 862 books out of 882
# Processed 863 books out of 882
# Processed 864 books out of 882
# Processed 865 books out of 882
# Processed 866 books out of 882
# Processed 867 books out of 882
# Processed 868 books out of 882
# Processed 869 books out of 882
# Processed 870 books out of 882
# Processed 871 books out of 882
# Processed 872 books out of 882
# Processed 873 books out of 882
# Processed 874 books out of 882
# Processed 875 books out of 882
# Processed 876 books out of 882
# Processed 877 books out of 882
# Processed 878 books out of 882
# Processed 879 books out of 882
# Processed 880 books out of 882
# Processed 881 books out of 882
# Processed 882 books out of 882

# %% [markdown]
# #### Same with 0.75 threshold

# %%
# Loading the data from the Excel file
excel_path = 'goodreads_data_with_additional_info.xlsx'
data = pd.read_excel(excel_path)

# Function to preprocess and clean text using SpaCy
nlp = spacy.load("en_core_web_md")

def clean_text_with_spacy(text):
    doc = nlp(text.lower())
    return " ".join([token.lemma_ for token in doc if not token.is_stop and token.is_alpha])

# List of popular book genres
popular_genres = ['Mystery', 'Thriller', 'Romance', 'Science Fiction', 'Fantasy', 'Historical Fiction',
                  'Horror', 'Crime', 'Biography', 'Memoir', 'Self-Help', 'Young Adult', "Children's",
                  'Adventure', 'Contemporary', 'Dystopian', 'Suspense', 'Poetry', 'Comedy', 'Drama', 'Action',
                  'Paranormal', 'Urban Fantasy', 'Science Fantasy', 'Humor', 'Travel', 'Philosophy', 'Classic']

# Preprocessing and cleaning popular genres
cleaned_popular_genres = [clean_text_with_spacy(genre) for genre in popular_genres]

# Creating an empty list to store top labels
top_labels = []

# Iterating over each row in the DataFrame
for index, row in data.iterrows():
    # Extracting labels from the 'Labels' column
    labels = ast.literal_eval(row['Labels'])

    # Removing empty strings from the list
    labels = [label for label in labels if label]

    # Preprocessing and clean labels
    cleaned_labels = [clean_text_with_spacy(label) for label in labels]

    # Combining both lists for vectorization
    combined_list = cleaned_labels + cleaned_popular_genres

    # Calculating word vectors for combined list
    vectors = [nlp(text).vector for text in combined_list]

    # Calculating cosine similarity
    cosine_sim = cosine_similarity(vectors)

    # Threshold for similarity
    threshold = 0.75

    # Filtering labels based on cosine similarity
    filtered_indices = [i for i, label in enumerate(labels) if any(cosine_sim[i, j] > threshold for j in range(len(cleaned_labels), len(combined_list)))]

    # Calculating maximum similarity score for each label with popular genres
    max_similarities = [max(cosine_sim[i, len(cleaned_labels):]) for i in filtered_indices]

    # Checking if any labels passed the similarity threshold
    if filtered_indices:
        # Getting the index of the label with the highest similarity score
        top_label_index = filtered_indices[max_similarities.index(max(max_similarities))]

        # Retrieving the top label
        top_label = labels[top_label_index]

        # Appending the top label to the list
        top_labels.append(top_label)
    else:
        # If no label met the similarity threshold, append None
        top_labels.append(None)

    # Printing progress update
    print(f"Processed {index + 1} books out of {len(data)}")

# Adding the top labels to the DataFrame
data['Top Label'] = top_labels

# Saving the updated DataFrame to a new Excel file
data.to_excel('goodreads_dataset-final-version-lower-sim.xlsx', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Processed 1 books out of 882
# Processed 2 books out of 882
# Processed 3 books out of 882
# Processed 4 books out of 882
# Processed 5 books out of 882
# Processed 6 books out of 882
# Processed 7 books out of 882
# Processed 8 books out of 882
# Processed 9 books out of 882
# Processed 10 books out of 882
# Processed 11 books out of 882
# Processed 12 books out of 882
# Processed 13 books out of 882
# Processed 14 books out of 882
# Processed 15 books out of 882
# Processed 16 books out of 882
# Processed 17 books out of 882
# Processed 18 books out of 882
# Processed 19 books out of 882
# Processed 20 books out of 882
# Processed 21 books out of 882
# Processed 22 books out of 882
# Processed 23 books out of 882
# Processed 24 books out of 882
# Processed 25 books out of 882
# Processed 26 books out of 882
# Processed 27 books out of 882
# Processed 28 books out of 882
# Processed 29 books out of 882
# Processed 30 books out of 882
# Processed 31 books out of 882
# Processed 32 books out of 882
# Processed 33 books out of 882
# Processed 34 books out of 882
# Processed 35 books out of 882
# Processed 36 books out of 882
# Processed 37 books out of 882
# Processed 38 books out of 882
# Processed 39 books out of 882
# Processed 40 books out of 882
# Processed 41 books out of 882
# Processed 42 books out of 882
# Processed 43 books out of 882
# Processed 44 books out of 882
# Processed 45 books out of 882
# Processed 46 books out of 882
# Processed 47 books out of 882
# Processed 48 books out of 882
# Processed 49 books out of 882
# Processed 50 books out of 882
# Processed 51 books out of 882
# Processed 52 books out of 882
# Processed 53 books out of 882
# Processed 54 books out of 882
# Processed 55 books out of 882
# Processed 56 books out of 882
# Processed 57 books out of 882
# Processed 58 books out of 882
# Processed 59 books out of 882
# Processed 60 books out of 882
# Processed 61 books out of 882
# Processed 62 books out of 882
# Processed 63 books out of 882
# Processed 64 books out of 882
# Processed 65 books out of 882
# Processed 66 books out of 882
# Processed 67 books out of 882
# Processed 68 books out of 882
# Processed 69 books out of 882
# Processed 70 books out of 882
# Processed 71 books out of 882
# Processed 72 books out of 882
# Processed 73 books out of 882
# Processed 74 books out of 882
# Processed 75 books out of 882
# Processed 76 books out of 882
# Processed 77 books out of 882
# Processed 78 books out of 882
# Processed 79 books out of 882
# Processed 80 books out of 882
# Processed 81 books out of 882
# Processed 82 books out of 882
# Processed 83 books out of 882
# Processed 84 books out of 882
# Processed 85 books out of 882
# Processed 86 books out of 882
# Processed 87 books out of 882
# Processed 88 books out of 882
# Processed 89 books out of 882
# Processed 90 books out of 882
# Processed 91 books out of 882
# Processed 92 books out of 882
# Processed 93 books out of 882
# Processed 94 books out of 882
# Processed 95 books out of 882
# Processed 96 books out of 882
# Processed 97 books out of 882
# Processed 98 books out of 882
# Processed 99 books out of 882
# Processed 100 books out of 882
# Processed 101 books out of 882
# Processed 102 books out of 882
# Processed 103 books out of 882
# Processed 104 books out of 882
# Processed 105 books out of 882
# Processed 106 books out of 882
# Processed 107 books out of 882
# Processed 108 books out of 882
# Processed 109 books out of 882
# Processed 110 books out of 882
# Processed 111 books out of 882
# Processed 112 books out of 882
# Processed 113 books out of 882
# Processed 114 books out of 882
# Processed 115 books out of 882
# Processed 116 books out of 882
# Processed 117 books out of 882
# Processed 118 books out of 882
# Processed 119 books out of 882
# Processed 120 books out of 882
# Processed 121 books out of 882
# Processed 122 books out of 882
# Processed 123 books out of 882
# Processed 124 books out of 882
# Processed 125 books out of 882
# Processed 126 books out of 882
# Processed 127 books out of 882
# Processed 128 books out of 882
# Processed 129 books out of 882
# Processed 130 books out of 882
# Processed 131 books out of 882
# Processed 132 books out of 882
# Processed 133 books out of 882
# Processed 134 books out of 882
# Processed 135 books out of 882
# Processed 136 books out of 882
# Processed 137 books out of 882
# Processed 138 books out of 882
# Processed 139 books out of 882
# Processed 140 books out of 882
# Processed 141 books out of 882
# Processed 142 books out of 882
# Processed 143 books out of 882
# Processed 144 books out of 882
# Processed 145 books out of 882
# Processed 146 books out of 882
# Processed 147 books out of 882
# Processed 148 books out of 882
# Processed 149 books out of 882
# Processed 150 books out of 882
# Processed 151 books out of 882
# Processed 152 books out of 882
# Processed 153 books out of 882
# Processed 154 books out of 882
# Processed 155 books out of 882
# Processed 156 books out of 882
# Processed 157 books out of 882
# Processed 158 books out of 882
# Processed 159 books out of 882
# Processed 160 books out of 882
# Processed 161 books out of 882
# Processed 162 books out of 882
# Processed 163 books out of 882
# Processed 164 books out of 882
# Processed 165 books out of 882
# Processed 166 books out of 882
# Processed 167 books out of 882
# Processed 168 books out of 882
# Processed 169 books out of 882
# Processed 170 books out of 882
# Processed 171 books out of 882
# Processed 172 books out of 882
# Processed 173 books out of 882
# Processed 174 books out of 882
# Processed 175 books out of 882
# Processed 176 books out of 882
# Processed 177 books out of 882
# Processed 178 books out of 882
# Processed 179 books out of 882
# Processed 180 books out of 882
# Processed 181 books out of 882
# Processed 182 books out of 882
# Processed 183 books out of 882
# Processed 184 books out of 882
# Processed 185 books out of 882
# Processed 186 books out of 882
# Processed 187 books out of 882
# Processed 188 books out of 882
# Processed 189 books out of 882
# Processed 190 books out of 882
# Processed 191 books out of 882
# Processed 192 books out of 882
# Processed 193 books out of 882
# Processed 194 books out of 882
# Processed 195 books out of 882
# Processed 196 books out of 882
# Processed 197 books out of 882
# Processed 198 books out of 882
# Processed 199 books out of 882
# Processed 200 books out of 882
# Processed 201 books out of 882
# Processed 202 books out of 882
# Processed 203 books out of 882
# Processed 204 books out of 882
# Processed 205 books out of 882
# Processed 206 books out of 882
# Processed 207 books out of 882
# Processed 208 books out of 882
# Processed 209 books out of 882
# Processed 210 books out of 882
# Processed 211 books out of 882
# Processed 212 books out of 882
# Processed 213 books out of 882
# Processed 214 books out of 882
# Processed 215 books out of 882
# Processed 216 books out of 882
# Processed 217 books out of 882
# Processed 218 books out of 882
# Processed 219 books out of 882
# Processed 220 books out of 882
# Processed 221 books out of 882
# Processed 222 books out of 882
# Processed 223 books out of 882
# Processed 224 books out of 882
# Processed 225 books out of 882
# Processed 226 books out of 882
# Processed 227 books out of 882
# Processed 228 books out of 882
# Processed 229 books out of 882
# Processed 230 books out of 882
# Processed 231 books out of 882
# Processed 232 books out of 882
# Processed 233 books out of 882
# Processed 234 books out of 882
# Processed 235 books out of 882
# Processed 236 books out of 882
# Processed 237 books out of 882
# Processed 238 books out of 882
# Processed 239 books out of 882
# Processed 240 books out of 882
# Processed 241 books out of 882
# Processed 242 books out of 882
# Processed 243 books out of 882
# Processed 244 books out of 882
# Processed 245 books out of 882
# Processed 246 books out of 882
# Processed 247 books out of 882
# Processed 248 books out of 882
# Processed 249 books out of 882
# Processed 250 books out of 882
# Processed 251 books out of 882
# Processed 252 books out of 882
# Processed 253 books out of 882
# Processed 254 books out of 882
# Processed 255 books out of 882
# Processed 256 books out of 882
# Processed 257 books out of 882
# Processed 258 books out of 882
# Processed 259 books out of 882
# Processed 260 books out of 882
# Processed 261 books out of 882
# Processed 262 books out of 882
# Processed 263 books out of 882
# Processed 264 books out of 882
# Processed 265 books out of 882
# Processed 266 books out of 882
# Processed 267 books out of 882
# Processed 268 books out of 882
# Processed 269 books out of 882
# Processed 270 books out of 882
# Processed 271 books out of 882
# Processed 272 books out of 882
# Processed 273 books out of 882
# Processed 274 books out of 882
# Processed 275 books out of 882
# Processed 276 books out of 882
# Processed 277 books out of 882
# Processed 278 books out of 882
# Processed 279 books out of 882
# Processed 280 books out of 882
# Processed 281 books out of 882
# Processed 282 books out of 882
# Processed 283 books out of 882
# Processed 284 books out of 882
# Processed 285 books out of 882
# Processed 286 books out of 882
# Processed 287 books out of 882
# Processed 288 books out of 882
# Processed 289 books out of 882
# Processed 290 books out of 882
# Processed 291 books out of 882
# Processed 292 books out of 882
# Processed 293 books out of 882
# Processed 294 books out of 882
# Processed 295 books out of 882
# Processed 296 books out of 882
# Processed 297 books out of 882
# Processed 298 books out of 882
# Processed 299 books out of 882
# Processed 300 books out of 882
# Processed 301 books out of 882
# Processed 302 books out of 882
# Processed 303 books out of 882
# Processed 304 books out of 882
# Processed 305 books out of 882
# Processed 306 books out of 882
# Processed 307 books out of 882
# Processed 308 books out of 882
# Processed 309 books out of 882
# Processed 310 books out of 882
# Processed 311 books out of 882
# Processed 312 books out of 882
# Processed 313 books out of 882
# Processed 314 books out of 882
# Processed 315 books out of 882
# Processed 316 books out of 882
# Processed 317 books out of 882
# Processed 318 books out of 882
# Processed 319 books out of 882
# Processed 320 books out of 882
# Processed 321 books out of 882
# Processed 322 books out of 882
# Processed 323 books out of 882
# Processed 324 books out of 882
# Processed 325 books out of 882
# Processed 326 books out of 882
# Processed 327 books out of 882
# Processed 328 books out of 882
# Processed 329 books out of 882
# Processed 330 books out of 882
# Processed 331 books out of 882
# Processed 332 books out of 882
# Processed 333 books out of 882
# Processed 334 books out of 882
# Processed 335 books out of 882
# Processed 336 books out of 882
# Processed 337 books out of 882
# Processed 338 books out of 882
# Processed 339 books out of 882
# Processed 340 books out of 882
# Processed 341 books out of 882
# Processed 342 books out of 882
# Processed 343 books out of 882
# Processed 344 books out of 882
# Processed 345 books out of 882
# Processed 346 books out of 882
# Processed 347 books out of 882
# Processed 348 books out of 882
# Processed 349 books out of 882
# Processed 350 books out of 882
# Processed 351 books out of 882
# Processed 352 books out of 882
# Processed 353 books out of 882
# Processed 354 books out of 882
# Processed 355 books out of 882
# Processed 356 books out of 882
# Processed 357 books out of 882
# Processed 358 books out of 882
# Processed 359 books out of 882
# Processed 360 books out of 882
# Processed 361 books out of 882
# Processed 362 books out of 882
# Processed 363 books out of 882
# Processed 364 books out of 882
# Processed 365 books out of 882
# Processed 366 books out of 882
# Processed 367 books out of 882
# Processed 368 books out of 882
# Processed 369 books out of 882
# Processed 370 books out of 882
# Processed 371 books out of 882
# Processed 372 books out of 882
# Processed 373 books out of 882
# Processed 374 books out of 882
# Processed 375 books out of 882
# Processed 376 books out of 882
# Processed 377 books out of 882
# Processed 378 books out of 882
# Processed 379 books out of 882
# Processed 380 books out of 882
# Processed 381 books out of 882
# Processed 382 books out of 882
# Processed 383 books out of 882
# Processed 384 books out of 882
# Processed 385 books out of 882
# Processed 386 books out of 882
# Processed 387 books out of 882
# Processed 388 books out of 882
# Processed 389 books out of 882
# Processed 390 books out of 882
# Processed 391 books out of 882
# Processed 392 books out of 882
# Processed 393 books out of 882
# Processed 394 books out of 882
# Processed 395 books out of 882
# Processed 396 books out of 882
# Processed 397 books out of 882
# Processed 398 books out of 882
# Processed 399 books out of 882
# Processed 400 books out of 882
# Processed 401 books out of 882
# Processed 402 books out of 882
# Processed 403 books out of 882
# Processed 404 books out of 882
# Processed 405 books out of 882
# Processed 406 books out of 882
# Processed 407 books out of 882
# Processed 408 books out of 882
# Processed 409 books out of 882
# Processed 410 books out of 882
# Processed 411 books out of 882
# Processed 412 books out of 882
# Processed 413 books out of 882
# Processed 414 books out of 882
# Processed 415 books out of 882
# Processed 416 books out of 882
# Processed 417 books out of 882
# Processed 418 books out of 882
# Processed 419 books out of 882
# Processed 420 books out of 882
# Processed 421 books out of 882
# Processed 422 books out of 882
# Processed 423 books out of 882
# Processed 424 books out of 882
# Processed 425 books out of 882
# Processed 426 books out of 882
# Processed 427 books out of 882
# Processed 428 books out of 882
# Processed 429 books out of 882
# Processed 430 books out of 882
# Processed 431 books out of 882
# Processed 432 books out of 882
# Processed 433 books out of 882
# Processed 434 books out of 882
# Processed 435 books out of 882
# Processed 436 books out of 882
# Processed 437 books out of 882
# Processed 438 books out of 882
# Processed 439 books out of 882
# Processed 440 books out of 882
# Processed 441 books out of 882
# Processed 442 books out of 882
# Processed 443 books out of 882
# Processed 444 books out of 882
# Processed 445 books out of 882
# Processed 446 books out of 882
# Processed 447 books out of 882
# Processed 448 books out of 882
# Processed 449 books out of 882
# Processed 450 books out of 882
# Processed 451 books out of 882
# Processed 452 books out of 882
# Processed 453 books out of 882
# Processed 454 books out of 882
# Processed 455 books out of 882
# Processed 456 books out of 882
# Processed 457 books out of 882
# Processed 458 books out of 882
# Processed 459 books out of 882
# Processed 460 books out of 882
# Processed 461 books out of 882
# Processed 462 books out of 882
# Processed 463 books out of 882
# Processed 464 books out of 882
# Processed 465 books out of 882
# Processed 466 books out of 882
# Processed 467 books out of 882
# Processed 468 books out of 882
# Processed 469 books out of 882
# Processed 470 books out of 882
# Processed 471 books out of 882
# Processed 472 books out of 882
# Processed 473 books out of 882
# Processed 474 books out of 882
# Processed 475 books out of 882
# Processed 476 books out of 882
# Processed 477 books out of 882
# Processed 478 books out of 882
# Processed 479 books out of 882
# Processed 480 books out of 882
# Processed 481 books out of 882
# Processed 482 books out of 882
# Processed 483 books out of 882
# Processed 484 books out of 882
# Processed 485 books out of 882
# Processed 486 books out of 882
# Processed 487 books out of 882
# Processed 488 books out of 882
# Processed 489 books out of 882
# Processed 490 books out of 882
# Processed 491 books out of 882
# Processed 492 books out of 882
# Processed 493 books out of 882
# Processed 494 books out of 882
# Processed 495 books out of 882
# Processed 496 books out of 882
# Processed 497 books out of 882
# Processed 498 books out of 882
# Processed 499 books out of 882
# Processed 500 books out of 882
# Processed 501 books out of 882
# Processed 502 books out of 882
# Processed 503 books out of 882
# Processed 504 books out of 882
# Processed 505 books out of 882
# Processed 506 books out of 882
# Processed 507 books out of 882
# Processed 508 books out of 882
# Processed 509 books out of 882
# Processed 510 books out of 882
# Processed 511 books out of 882
# Processed 512 books out of 882
# Processed 513 books out of 882
# Processed 514 books out of 882
# Processed 515 books out of 882
# Processed 516 books out of 882
# Processed 517 books out of 882
# Processed 518 books out of 882
# Processed 519 books out of 882
# Processed 520 books out of 882
# Processed 521 books out of 882
# Processed 522 books out of 882
# Processed 523 books out of 882
# Processed 524 books out of 882
# Processed 525 books out of 882
# Processed 526 books out of 882
# Processed 527 books out of 882
# Processed 528 books out of 882
# Processed 529 books out of 882
# Processed 530 books out of 882
# Processed 531 books out of 882
# Processed 532 books out of 882
# Processed 533 books out of 882
# Processed 534 books out of 882
# Processed 535 books out of 882
# Processed 536 books out of 882
# Processed 537 books out of 882
# Processed 538 books out of 882
# Processed 539 books out of 882
# Processed 540 books out of 882
# Processed 541 books out of 882
# Processed 542 books out of 882
# Processed 543 books out of 882
# Processed 544 books out of 882
# Processed 545 books out of 882
# Processed 546 books out of 882
# Processed 547 books out of 882
# Processed 548 books out of 882
# Processed 549 books out of 882
# Processed 550 books out of 882
# Processed 551 books out of 882
# Processed 552 books out of 882
# Processed 553 books out of 882
# Processed 554 books out of 882
# Processed 555 books out of 882
# Processed 556 books out of 882
# Processed 557 books out of 882
# Processed 558 books out of 882
# Processed 559 books out of 882
# Processed 560 books out of 882
# Processed 561 books out of 882
# Processed 562 books out of 882
# Processed 563 books out of 882
# Processed 564 books out of 882
# Processed 565 books out of 882
# Processed 566 books out of 882
# Processed 567 books out of 882
# Processed 568 books out of 882
# Processed 569 books out of 882
# Processed 570 books out of 882
# Processed 571 books out of 882
# Processed 572 books out of 882
# Processed 573 books out of 882
# Processed 574 books out of 882
# Processed 575 books out of 882
# Processed 576 books out of 882
# Processed 577 books out of 882
# Processed 578 books out of 882
# Processed 579 books out of 882
# Processed 580 books out of 882
# Processed 581 books out of 882
# Processed 582 books out of 882
# Processed 583 books out of 882
# Processed 584 books out of 882
# Processed 585 books out of 882
# Processed 586 books out of 882
# Processed 587 books out of 882
# Processed 588 books out of 882
# Processed 589 books out of 882
# Processed 590 books out of 882
# Processed 591 books out of 882
# Processed 592 books out of 882
# Processed 593 books out of 882
# Processed 594 books out of 882
# Processed 595 books out of 882
# Processed 596 books out of 882
# Processed 597 books out of 882
# Processed 598 books out of 882
# Processed 599 books out of 882
# Processed 600 books out of 882
# Processed 601 books out of 882
# Processed 602 books out of 882
# Processed 603 books out of 882
# Processed 604 books out of 882
# Processed 605 books out of 882
# Processed 606 books out of 882
# Processed 607 books out of 882
# Processed 608 books out of 882
# Processed 609 books out of 882
# Processed 610 books out of 882
# Processed 611 books out of 882
# Processed 612 books out of 882
# Processed 613 books out of 882
# Processed 614 books out of 882
# Processed 615 books out of 882
# Processed 616 books out of 882
# Processed 617 books out of 882
# Processed 618 books out of 882
# Processed 619 books out of 882
# Processed 620 books out of 882
# Processed 621 books out of 882
# Processed 622 books out of 882
# Processed 623 books out of 882
# Processed 624 books out of 882
# Processed 625 books out of 882
# Processed 626 books out of 882
# Processed 627 books out of 882
# Processed 628 books out of 882
# Processed 629 books out of 882
# Processed 630 books out of 882
# Processed 631 books out of 882
# Processed 632 books out of 882
# Processed 633 books out of 882
# Processed 634 books out of 882
# Processed 635 books out of 882
# Processed 636 books out of 882
# Processed 637 books out of 882
# Processed 638 books out of 882
# Processed 639 books out of 882
# Processed 640 books out of 882
# Processed 641 books out of 882
# Processed 642 books out of 882
# Processed 643 books out of 882
# Processed 644 books out of 882
# Processed 645 books out of 882
# Processed 646 books out of 882
# Processed 647 books out of 882
# Processed 648 books out of 882
# Processed 649 books out of 882
# Processed 650 books out of 882
# Processed 651 books out of 882
# Processed 652 books out of 882
# Processed 653 books out of 882
# Processed 654 books out of 882
# Processed 655 books out of 882
# Processed 656 books out of 882
# Processed 657 books out of 882
# Processed 658 books out of 882
# Processed 659 books out of 882
# Processed 660 books out of 882
# Processed 661 books out of 882
# Processed 662 books out of 882
# Processed 663 books out of 882
# Processed 664 books out of 882
# Processed 665 books out of 882
# Processed 666 books out of 882
# Processed 667 books out of 882
# Processed 668 books out of 882
# Processed 669 books out of 882
# Processed 670 books out of 882
# Processed 671 books out of 882
# Processed 672 books out of 882
# Processed 673 books out of 882
# Processed 674 books out of 882
# Processed 675 books out of 882
# Processed 676 books out of 882
# Processed 677 books out of 882
# Processed 678 books out of 882
# Processed 679 books out of 882
# Processed 680 books out of 882
# Processed 681 books out of 882
# Processed 682 books out of 882
# Processed 683 books out of 882
# Processed 684 books out of 882
# Processed 685 books out of 882
# Processed 686 books out of 882
# Processed 687 books out of 882
# Processed 688 books out of 882
# Processed 689 books out of 882
# Processed 690 books out of 882
# Processed 691 books out of 882
# Processed 692 books out of 882
# Processed 693 books out of 882
# Processed 694 books out of 882
# Processed 695 books out of 882
# Processed 696 books out of 882
# Processed 697 books out of 882
# Processed 698 books out of 882
# Processed 699 books out of 882
# Processed 700 books out of 882
# Processed 701 books out of 882
# Processed 702 books out of 882
# Processed 703 books out of 882
# Processed 704 books out of 882
# Processed 705 books out of 882
# Processed 706 books out of 882
# Processed 707 books out of 882
# Processed 708 books out of 882
# Processed 709 books out of 882
# Processed 710 books out of 882
# Processed 711 books out of 882
# Processed 712 books out of 882
# Processed 713 books out of 882
# Processed 714 books out of 882
# Processed 715 books out of 882
# Processed 716 books out of 882
# Processed 717 books out of 882
# Processed 718 books out of 882
# Processed 719 books out of 882
# Processed 720 books out of 882
# Processed 721 books out of 882
# Processed 722 books out of 882
# Processed 723 books out of 882
# Processed 724 books out of 882
# Processed 725 books out of 882
# Processed 726 books out of 882
# Processed 727 books out of 882
# Processed 728 books out of 882
# Processed 729 books out of 882
# Processed 730 books out of 882
# Processed 731 books out of 882
# Processed 732 books out of 882
# Processed 733 books out of 882
# Processed 734 books out of 882
# Processed 735 books out of 882
# Processed 736 books out of 882
# Processed 737 books out of 882
# Processed 738 books out of 882
# Processed 739 books out of 882
# Processed 740 books out of 882
# Processed 741 books out of 882
# Processed 742 books out of 882
# Processed 743 books out of 882
# Processed 744 books out of 882
# Processed 745 books out of 882
# Processed 746 books out of 882
# Processed 747 books out of 882
# Processed 748 books out of 882
# Processed 749 books out of 882
# Processed 750 books out of 882
# Processed 751 books out of 882
# Processed 752 books out of 882
# Processed 753 books out of 882
# Processed 754 books out of 882
# Processed 755 books out of 882
# Processed 756 books out of 882
# Processed 757 books out of 882
# Processed 758 books out of 882
# Processed 759 books out of 882
# Processed 760 books out of 882
# Processed 761 books out of 882
# Processed 762 books out of 882
# Processed 763 books out of 882
# Processed 764 books out of 882
# Processed 765 books out of 882
# Processed 766 books out of 882
# Processed 767 books out of 882
# Processed 768 books out of 882
# Processed 769 books out of 882
# Processed 770 books out of 882
# Processed 771 books out of 882
# Processed 772 books out of 882
# Processed 773 books out of 882
# Processed 774 books out of 882
# Processed 775 books out of 882
# Processed 776 books out of 882
# Processed 777 books out of 882
# Processed 778 books out of 882
# Processed 779 books out of 882
# Processed 780 books out of 882
# Processed 781 books out of 882
# Processed 782 books out of 882
# Processed 783 books out of 882
# Processed 784 books out of 882
# Processed 785 books out of 882
# Processed 786 books out of 882
# Processed 787 books out of 882
# Processed 788 books out of 882
# Processed 789 books out of 882
# Processed 790 books out of 882
# Processed 791 books out of 882
# Processed 792 books out of 882
# Processed 793 books out of 882
# Processed 794 books out of 882
# Processed 795 books out of 882
# Processed 796 books out of 882
# Processed 797 books out of 882
# Processed 798 books out of 882
# Processed 799 books out of 882
# Processed 800 books out of 882
# Processed 801 books out of 882
# Processed 802 books out of 882
# Processed 803 books out of 882
# Processed 804 books out of 882
# Processed 805 books out of 882
# Processed 806 books out of 882
# Processed 807 books out of 882
# Processed 808 books out of 882
# Processed 809 books out of 882
# Processed 810 books out of 882
# Processed 811 books out of 882
# Processed 812 books out of 882
# Processed 813 books out of 882
# Processed 814 books out of 882
# Processed 815 books out of 882
# Processed 816 books out of 882
# Processed 817 books out of 882
# Processed 818 books out of 882
# Processed 819 books out of 882
# Processed 820 books out of 882
# Processed 821 books out of 882
# Processed 822 books out of 882
# Processed 823 books out of 882
# Processed 824 books out of 882
# Processed 825 books out of 882
# Processed 826 books out of 882
# Processed 827 books out of 882
# Processed 828 books out of 882
# Processed 829 books out of 882
# Processed 830 books out of 882
# Processed 831 books out of 882
# Processed 832 books out of 882
# Processed 833 books out of 882
# Processed 834 books out of 882
# Processed 835 books out of 882
# Processed 836 books out of 882
# Processed 837 books out of 882
# Processed 838 books out of 882
# Processed 839 books out of 882
# Processed 840 books out of 882
# Processed 841 books out of 882
# Processed 842 books out of 882
# Processed 843 books out of 882
# Processed 844 books out of 882
# Processed 845 books out of 882
# Processed 846 books out of 882
# Processed 847 books out of 882
# Processed 848 books out of 882
# Processed 849 books out of 882
# Processed 850 books out of 882
# Processed 851 books out of 882
# Processed 852 books out of 882
# Processed 853 books out of 882
# Processed 854 books out of 882
# Processed 855 books out of 882
# Processed 856 books out of 882
# Processed 857 books out of 882
# Processed 858 books out of 882
# Processed 859 books out of 882
# Processed 860 books out of 882
# Processed 861 books out of 882
# Processed 862 books out of 882
# Processed 863 books out of 882
# Processed 864 books out of 882
# Processed 865 books out of 882
# Processed 866 books out of 882
# Processed 867 books out of 882
# Processed 868 books out of 882
# Processed 869 books out of 882
# Processed 870 books out of 882
# Processed 871 books out of 882
# Processed 872 books out of 882
# Processed 873 books out of 882
# Processed 874 books out of 882
# Processed 875 books out of 882
# Processed 876 books out of 882
# Processed 877 books out of 882
# Processed 878 books out of 882
# Processed 879 books out of 882
# Processed 880 books out of 882
# Processed 881 books out of 882
# Processed 882 books out of 882
